# %%
#  Q. “안녕 파이썬!” 이라는 문구가 코랩 노트 결과 화면에 출력되도록 해주세요.

# %%
print("안녕 파이썬!")
# Out:
# 안녕 파이썬!

# %%
# Q. “23+31” 결과가 다음과 같이 출력되도록 파이썬 코드를 작성해주세요.

# %%
print("결과 : ", 23 + 31)
# Out:
# 결과 :  54

# %%
# Q. 아래의 결과가 출력되도록 파이썬 코드를 작성해주세요. 단, 공백문자를(” “) 사용하지 않고 출력해주세요.

# %%
print("A", "B")
print("A" + "B")
# Out:
# A B
# AB
