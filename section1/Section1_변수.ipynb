# %%
# Q. 변수 x에 숫자 10을 넣고 출력해보세요.

# %%
x = 10
print(x)
# Out:
# 10

# %%
# Q."파이썬"이라는 글자를 name이라는 변수에 저장하고, 그 값을 출력하려면 어떻게 해야 할까요?

# %%
name = "파이썬"
print(name)          # 파이썬
# Out:
# 파이썬

# %%
# Q. 나이를 의미하는 age라는 변수에 숫자 25를 저장하고, 그 값을 출력해보세요.

# %%
age = 25
print(age)           # 25
# Out:
# 25

# %%
# Q. 물건 가격을 price라는 변수에 저장한 뒤, "가격: "이라는 글자와 함께 출력하려면 어떻게 해야 할까요?

# %%
price = 9900
print("가격:", price)  # 가격: 9900
# Out:
# 가격: 9900
