# %%
# Q. “안녕하세요”를 출력하는 함수 greet()를 만들어 실행해보세요.

# %%
def greet():
    print("안녕하세요")

greet()
# Out:
# 안녕하세요

# %%
# Q. 이름을 받아서 인사해주는 함수 say_hello(name)를 만들어보세요.

# %%
def say_hello(name):
    print("안녕,", name)

say_hello("파이썬")
# Out:
# 안녕, 파이썬

# %%
# Q. 두 숫자를 더해서 결과를 돌려주는 함수 add(x, y)를 만들어보세요.

# %%
def add(x, y):
    return x + y

result = add(3, 5)
print("결과:", result)
# Out:
# 결과: 8

# %%
# Q. Person이라는 클래스를 만들고, 이름을 출력하는 기능을 넣어보세요.

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def say_name(self):
        print("저는", self.name, "입니다.")

p = Person("파이썬")
p.say_name()
# Out:
# 저는 파이썬 입니다.

# %%
# Person이라는 클래스를 만들고, 이름을 출력하는 기능을 넣어보세요. 함수명은 say_name으로 해주세요. “저는 (이름) 입니다.” 이렇게 출력되도록 해주세요

# %%
class Person:
    def __init__(self, name):
        self.name = name

    def say_name(self):
        print("저는", self.name, "입니다.")

p = Person("홍길동")
p.say_name()
# Out:
# 저는 홍길동 입니다.
